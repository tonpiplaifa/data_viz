# %% [markdown]
# <a href="https://colab.research.google.com/github/tonpiplaifa/data_viz/blob/main/Quiz4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
P6364 = pd.read_excel('/content/passenger-covid19.xlsx',sheet_name=1)
P6364.head()
# Out:
#   ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-13 00:00:00 2021-03-14 00:00:00
# 0     ขนคน (คน)          ทางบก  ...             51204.0             58371.0
# 1     ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 2     ขนคน (คน)          ทางบก  ...             11373.0             12455.0
# 3    ขนคน (คัน)          ทางบก  ...            940739.0            870772.0
# 4    ขนคน (คัน)          ทางบก  ...           1348121.0           1211478.0
#
# [5 rows x 445 columns]

# %%
P6364['สาธารณะ/ส่วนบุคคล']
# Out:
# 0     สาธารณะ
# 1     สาธารณะ
# 2     สาธารณะ
# 3     สาธารณะ
# 4     สาธารณะ
# 5     สาธารณะ
# 6     สาธารณะ
# 7     สาธารณะ
# 8     สาธารณะ
# 9     สาธารณะ
# 10    สาธารณะ
# 11    สาธารณะ
# 12    สาธารณะ
# 13    สาธารณะ
# 14    สาธารณะ
# 15    สาธารณะ
# 16    สาธารณะ
# 17    สาธารณะ
# 18    สาธารณะ
# 19    สาธารณะ
# 20    สาธารณะ
# 21    สาธารณะ
# 22    สาธารณะ
# 23    สาธารณะ
# 24    สาธารณะ
# 25    สาธารณะ
# 26    สาธารณะ
# 27    สาธารณะ
# 28    สาธารณะ
# 29    สาธารณะ
# 30    สาธารณะ
# 31    สาธารณะ
# 32    สาธารณะ
# 33    สาธารณะ
# 34    สาธารณะ
# 35    สาธารณะ
# 36    สาธารณะ
# 37    สาธารณะ
# 38    สาธารณะ
# 39    สาธารณะ
# 40    สาธารณะ
# 41    สาธารณะ
# 42    สาธารณะ
# Name: สาธารณะ/ส่วนบุคคล, dtype: object
