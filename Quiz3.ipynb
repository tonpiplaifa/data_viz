# %% [markdown]
# <a href="https://colab.research.google.com/github/tonpiplaifa/data_viz/blob/main/Quiz3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
path = '/content/drive/My Drive/Data_viz'

# %%
sale_file_path = os.path.join(path,'-.57-.58-1.xls')
print(sale_file_path)
# Out:
# /content/drive/My Drive/Data_viz/-.57-.58-1.xls

# %%
saleT57 = pd.read_excel(sale_file_path,sheet_name='ตค.57',skiprows=1)
saleT57.head()
# Out:
#   สรุปผลการดำเนินการจัดซื้อในรอบเดือน ตุลาคม 2557  ...                Unnamed: 8
# 0      สำนักงานปลัดกระทรวงวิทยาศาสตร์และเทคโนโลยี  ...                       NaN
# 1                                             NaN  ...                       NaN
# 2                                           ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 3                                             ที่  ...                       NaN
# 4                                               1  ...   เป็นผู้ให้บริการจำหน่าย
#
# [5 rows x 9 columns]

# %%
saleP57 = pd.read_excel(sale_file_path,sheet_name='พย.57',skiprows=1)
saleP57.head()
# Out:
#   สรุปผลการดำเนินการจัดซื้อในรอบเดือน พฤษจิกายน 2557  ...                Unnamed: 8
# 0         สำนักงานปลัดกระทรวงวิทยาศาสตร์และเทคโนโลยี  ...                       NaN
# 1                                                NaN  ...                       NaN
# 2                                              ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 3                                                ที่  ...                       NaN
# 4                                                  1  ...   เป็นผู้ให้บริการจำหน่าย
#
# [5 rows x 9 columns]

# %% [markdown]
# เฉลย

# %%
saleOct57 = pd.read_excel(sale_file_path,sheet_name=0,header=4,skipfooter=20)
oct57drop = saleOct57.dropna()
oct57drop
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
#
# [15 rows x 9 columns]

# %%
oct57drop.rename(columns={'Unnamed: 5':'ราคาเสนอ','Unnamed: 7':'ราคาซื้อ'}) #เปลี่ยนชื่อคอลัม
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
#
# [15 rows x 9 columns]

# %% [markdown]
# ##การบ้าน HW8

# %%
saleNov57 = pd.read_excel(sale_file_path,sheet_name=1,header=4,skipfooter=20)
nov57drop = saleNov57.dropna()
nov57drop
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...           เป็นผู้จำหน่าย
# 3      3  ...           เป็นผู้จำหน่าย
# 4      4  ...           เป็นผู้จำหน่าย
# 5      5  ...           เป็นผู้จำหน่าย
# 6      6  ...           เป็นผู้จำหน่าย
# 7      7  ...           เป็นผู้จำหน่าย
# 8      8  ...           เป็นผู้จำหน่าย
# 9      9  ...           เป็นผู้จำหน่าย
# 10    10  ...           เป็นผู้จำหน่าย
# 11    11  ...           เป็นผู้จำหน่าย
# 12    12  ...           เป็นผู้จำหน่าย
# 13    13  ...           เป็นผู้จำหน่าย
# 14    14  ...           เป็นผู้จำหน่าย
# 15    15  ...           เป็นผู้จำหน่าย
# 22    16  ...           เป็นผู้จำหน่าย
# 23    17  ...           เป็นผู้จำหน่าย
# 24    18  ...           เป็นผู้จำหน่าย
# 25    19  ...           เป็นผู้จำหน่าย
# 26    20  ...           เป็นผู้จำหน่าย
# 27    21  ...           เป็นผู้จำหน่าย
# 28    22  ...           เป็นผู้จำหน่าย
# 29    23  ...           เป็นผู้จำหน่าย
# ...

# %%
nov57drop.rename(columns={'Unnamed: 5':'ราคาเสนอ','Unnamed: 7':'ราคาซื้อ'}) #เปลี่ยนชื่อคอลัม
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...           เป็นผู้จำหน่าย
# 3      3  ...           เป็นผู้จำหน่าย
# 4      4  ...           เป็นผู้จำหน่าย
# 5      5  ...           เป็นผู้จำหน่าย
# 6      6  ...           เป็นผู้จำหน่าย
# 7      7  ...           เป็นผู้จำหน่าย
# 8      8  ...           เป็นผู้จำหน่าย
# 9      9  ...           เป็นผู้จำหน่าย
# 10    10  ...           เป็นผู้จำหน่าย
# 11    11  ...           เป็นผู้จำหน่าย
# 12    12  ...           เป็นผู้จำหน่าย
# 13    13  ...           เป็นผู้จำหน่าย
# 14    14  ...           เป็นผู้จำหน่าย
# 15    15  ...           เป็นผู้จำหน่าย
# 22    16  ...           เป็นผู้จำหน่าย
# 23    17  ...           เป็นผู้จำหน่าย
# 24    18  ...           เป็นผู้จำหน่าย
# 25    19  ...           เป็นผู้จำหน่าย
# 26    20  ...           เป็นผู้จำหน่าย
# 27    21  ...           เป็นผู้จำหน่าย
# 28    22  ...           เป็นผู้จำหน่าย
# 29    23  ...           เป็นผู้จำหน่าย
# ...

# %%
OctandNov57 = pd.concat([oct57drop,nov57drop]) #ต่อสองตารางในแนวแกน y
OctandNov57
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...           เป็นผู้จำหน่าย
# 3      3  ...           เป็นผู้จำหน่าย
# 4      4  ...           เป็นผู้จำหน่าย
# 5      5  ...           เป็นผู้จำหน่าย
# 6      6  ...           เป็นผู้จำหน่าย
# 7      7  ...           เป็นผู้จำหน่าย
# 8      8  ...           เป็นผู้จำหน่าย
# ...
